# %% [markdown]
# <b>Dictionary

# %% [markdown]
# It is collection of Key and Values
#
# Key is immutable and unique
#
# Values are mutable

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(car["brand"])
print(car["model"])
print(car["year"])

print(car)
# Out:
# Ford
# Mustang
# 1964
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# Mustang

# %%
l={1:100,2:"James"}
