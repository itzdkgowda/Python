# %%
str='python'
res=str*3
print(res)
# Out:
# pythonpythonpython

# %%
l=[1,2,3]

print(l*3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
l=[1,3,5]

print(l[0]*4)  # Here it work has muliplication
# Out:
# 4

# %%
l=[[1,2],3,5]

print(l[0]*2)0
# Out:
# [1, 2, 1, 2]

# %%
l=["raja",[1,2],55,6]

print(l[1][::-1])
# Out:
# [2, 1]

# %%
d={'name':'james','age':20}

print(list(d)[::-1])  # only key can be converted into list
# Out:
# ['age', 'name']
