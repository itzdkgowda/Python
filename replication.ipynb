# %%
str='python'
res=str*3
print(res)
# Out:
# pythonpythonpython

# %%
l=[1,2,3]

print(l*3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
l=[1,3,5]

print(l[0]*4)  # Here it work has muliplication
# Out:
# 4
