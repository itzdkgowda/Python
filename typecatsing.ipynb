# %%
l=[1,2,3,4,6]

# %%
print(str(l))
# Out:
# [1, 2, 3, 4, 6]

# %%
print(tuple(l))
# Out:
# (1, 2, 3, 4, 6)

# %%
print(dict(l))
#not possible
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(dict(l))
#
# NameError: name 'l' is not defined

# %%
l2=[('name','buuny'),(1,2)]

print(dict(l2))
# Out:
# {'name': 'buuny', 1: 2}

# %%
l1=(1,2,3.4,44,4)
print(l1)
# Out:
# (1, 2, 3.4, 44, 4)
